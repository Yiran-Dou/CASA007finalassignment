# %% [markdown]
# ## import packages

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
import os
from requests import get
from urllib.parse import urlparse

# %% [markdown]
# ## import London and charging points map

# %% [markdown]
# London:

# %%
url = "https://github.com/Yiran-Dou/CASA007finalassignment/blob/main/LONDON.gpkg?raw=true"
london = gpd.read_file(url)

london.plot(edgecolor='gray', facecolor='white', linewidth=1.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Charging points:

# %%
charging_point = gpd.read_file('https://github.com/Yiran-Dou/CASA007finalassignment/blob/main/Rapid_charging_points.gpkg?raw=true')
charging_point.plot(markersize=6,color='darkorange')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))

london.plot(edgecolor='gray', facecolor='wheat', linewidth=1,ax=ax)
charging_point.plot(markersize=6,color='red',ax=ax)

plt.savefig('LondonPoints')
plt.show()

# %% [markdown]
# ## Descriptive statistics

# %%
url1= "https://raw.githubusercontent.com/Yiran-Dou/CASA007finalassignment/main/csvfiles/price.csv"
price= pd.read_csv(url1, encoding='latin-1')

print(price.isnull().sum())
# Out:
# time              0
# fuel_price        0
# electric_price    0
# dtype: int64

# %%
plt.plot(price['time'], price['fuel_price'], label='fuel')
plt.plot(price['time'], price['electric_price'], label='electric')
plt.legend()  

plt.subplots_adjust(bottom=0.15)
plt.xlabel("time")
plt.xticks(rotation=45)
plt.ylabel("price")
plt.title("fuel and electricity price") 
plt.savefig('price')
plt.show()

# %%
url2= "https://raw.githubusercontent.com/Yiran-Dou/CASA007finalassignment/main/csvfiles/mileage.csv"
milleage= pd.read_csv(url2, encoding='latin-1')

print(milleage.isnull().sum())
# Out:
# year                1
# billion_mileage     1
# Unnamed: 2         72
# Unnamed: 3         72
# Unnamed: 4         72
# Unnamed: 5         72
# Unnamed: 6         72
# Unnamed: 7         72
# Unnamed: 8         72
# Unnamed: 9         72
# Unnamed: 10        72
# Unnamed: 11        72
# dtype: int64

# %%
milleage=milleage.dropna(how='all')
milleage
# Out:
#       year  billion_mileage  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   1949.0             46.5         NaN         NaN         NaN         NaN
# 1   1950.0             53.1         NaN         NaN         NaN         NaN
# 2   1951.0             58.9         NaN         NaN         NaN         NaN
# 3   1952.0             60.8         NaN         NaN         NaN         NaN
# 4   1953.0             64.9         NaN         NaN         NaN         NaN
# ..     ...              ...         ...         ...         ...         ...
# 66  2015.0            530.4         NaN         NaN         NaN         NaN
# 67  2016.0            544.3         NaN         NaN         NaN         NaN
# 68  2017.0            555.5         NaN         NaN         NaN         NaN
# 69  2018.0            562.5         NaN         NaN         NaN         NaN
# 70  2019.0            573.8         NaN         NaN         NaN         NaN
#
# ...

# %%
url3= "https://raw.githubusercontent.com/Yiran-Dou/CASA007finalassignment/main/csvfiles/gas_emission.csv"
gas= pd.read_csv(url3, encoding='latin-1')

print(gas.isnull().sum())
# Out:
# type     0
# Total    0
# dtype: int64

# %%
plt.plot(gas['type'], gas['Total'], label='gas emission')
plt.plot(milleage['year'], milleage['billion_mileage'], label='milleage')
plt.legend()  

plt.subplots_adjust(bottom=0.15)
plt.xlabel("year")
plt.xlim([1990,2020])
plt.xticks(rotation=45)
plt.ylabel("billion")
plt.title("milleage and gas emission") 
plt.savefig('milleage')
plt.show()

# %%
url4= "https://raw.githubusercontent.com/Yiran-Dou/CASA007finalassignment/main/csvfiles/encourage_factors.csv"
ef= pd.read_csv(url4, encoding='latin-1')

print(ef.isnull().sum())
# Out:
# Encourage_factors     0
# 2014 (Feb)            0
# 2015 (Feb)            0
# 2016 (Feb)            0
# Unnamed: 4           12
#                      ..
# Unnamed: 1015        12
# Unnamed: 1016        12
# Unnamed: 1017        12
# Unnamed: 1018        12
# Unnamed: 1019        12
# Length: 1020, dtype: int64

# %%
url5= "https://raw.githubusercontent.com/Yiran-Dou/CASA007finalassignment/main/csvfiles/electric_chargepoint.csv"
charg= pd.read_csv(url5, encoding='latin-1')

print(charg.isnull().sum())
# Out:
# Hour                    0
# Number                  0
# Mean_duration_time      0
# Mean_charge_supplied    0
# dtype: int64

# %%
from sklearn.cluster import KMeans

# %%
plt.plot(charg['Hour'], charg['Number'],color="r",linestyle="dashdot",
         linewidth=1,marker="o",markersize=5,label="Number")
plt.title("Charing Numbers",loc="center")

plt.grid(True)
plt.legend()
plt.savefig('cn')
plt.show()

# %%
plt.plot(charg['Hour'], charg['Mean_duration_time'], label='time')
plt.plot(charg['Hour'], charg['Mean_charge_supplied'], label='energy')
plt.title("Charing",loc="center")

plt.grid(True)
plt.legend()
plt.savefig('ch')
plt.show()

# %%
import seaborn as sns    
from statsmodels.graphics.tsaplots import plot_acf 
from statsmodels.tsa.stattools import adfuller as ADF 
from statsmodels.graphics.tsaplots import plot_pacf    
from statsmodels.stats.diagnostic import acorr_ljungbox    
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller

# %%
vehicle= pd.read_csv('vehicle_thousand.csv', encoding='latin-1')

print(vehicle.isnull().sum())
# Out:
# Year       0
# Petrol     0
# Diesel     0
# Eletric    0
# Gas        0
# Other      0
# Total      0
# dtype: int64

# %%
plt.scatter(vehicle['Year'], vehicle['Eletric'])
plt.title("electric",loc="center")
plt.grid(True)
plt.show()

# %%
x = vehicle[["Year"]]
y = vehicle[["Eletric"]]
font = {
    'family' : 'SimHei'
};
matplotlib.rc('font', **font)
matplotlib.rcParams['axes.unicode_minus'] = False

from pandas.plotting import scatter_matrix

scatter_matrix(
    vehicle[["Year", "Eletric"]], 
    alpha=0.8, figsize=(10, 10), diagonal='kde'
)
plt.savefig('1')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
x

pf = PolynomialFeatures(degree=2)  
x_2_fit = pf.fit_transform(x)

x_2_fit
# Out:
# array([[1.000000e+00, 1.994000e+03, 3.976036e+06],
#        [1.000000e+00, 1.995000e+03, 3.980025e+06],
#        [1.000000e+00, 1.996000e+03, 3.984016e+06],
#        [1.000000e+00, 1.997000e+03, 3.988009e+06],
#        [1.000000e+00, 1.998000e+03, 3.992004e+06],
#        [1.000000e+00, 1.999000e+03, 3.996001e+06],
#        [1.000000e+00, 2.000000e+03, 4.000000e+06],
#        [1.000000e+00, 2.001000e+03, 4.004001e+06],
#        [1.000000e+00, 2.002000e+03, 4.008004e+06],
#        [1.000000e+00, 2.003000e+03, 4.012009e+06],
#        [1.000000e+00, 2.004000e+03, 4.016016e+06],
#        [1.000000e+00, 2.005000e+03, 4.020025e+06],
#        [1.000000e+00, 2.006000e+03, 4.024036e+06],
#        [1.000000e+00, 2.007000e+03, 4.028049e+06],
#        [1.000000e+00, 2.008000e+03, 4.032064e+06],
#        [1.000000e+00, 2.009000e+03, 4.036081e+06],
#        [1.000000e+00, 2.010000e+03, 4.040100e+06],
#        [1.000000e+00, 2.011000e+03, 4.044121e+06],
# ...

# %%
lrModel = LinearRegression()
lrModel.fit(x_2_fit, y)  
lrModel.score(x_2_fit, y)
# Out:
# 0.9843994047533223

# %%
print(lrModel.coef_)
print(lrModel.intercept_)
# Out:
# [[ 0.00000000e+00  3.07160922e+04 -7.55256105e+00]]
# [-31197441.31702162]

# %%
x_2_predict = pf.fit_transform([[2021], [2022], [2023],[2024],[2025],[2026],[2027],[2028],[2029],[2030]]) 
lrModel.predict(x_2_predict)
# Out:
# array([[31791.10604258],
#        [31972.19396319],
#        [32138.17676171],
#        [32289.05443812],
#        [32424.82699243],
#        [32545.49442464],
#        [32651.05673476],
#        [32741.51392277],
#        [32816.86598867],
#        [32877.11293248]])

# %%
plt.scatter(vehicle['Year'], vehicle['Diesel'])
plt.title("Diesel",loc="center")
plt.grid(True)
plt.show()

# %%
plt.scatter(vehicle['Year'], vehicle['Total'])
plt.title("total",loc="center")
plt.grid(True)
plt.show()

# %%
plt.scatter(vehicle['Year'], vehicle['Gas'])
plt.scatter(vehicle['Year'], vehicle['Other'])
plt.title("Gas",loc="center")
plt.grid(True)
plt.show()

# %%
url= "https://raw.githubusercontent.com/Yiran-Dou/CASA007finalassignment/main/MR.csv"
df = pd.read_csv(url, encoding='latin-1')
df.pop('Year')
print(df.isnull().sum())
# Out:
# PHEV               0
# BEV                0
# HEV                0
# gas_emission       0
# Total              0
# billion_mileage    0
# dtype: int64

# %%
print(df.describe())
# Out:
#                PHEV           BEV           HEV  gas_emission       Total  \
# count     24.000000     24.000000     24.000000     24.000000   24.000000
# mean    4813.333333   2302.500000  17153.750000     -0.008333  437.264583
# std    10655.671960   4206.494203  21687.751264      2.019668  226.316686
# min        0.000000    -20.000000      0.000000     -5.100000   46.410000
# 25%        0.000000     40.000000    285.000000     -0.925000  301.855000
# 50%        0.000000    130.000000  11450.000000     -0.100000  444.540000
# 75%      575.000000   1620.000000  23267.500000      1.150000  609.815000
# max    37020.000000  14120.000000  78990.000000      4.100000  843.440000
#
#        billion_mileage
# count        24.000000
# mean          5.875000
# std           5.785082
# min          -4.800000
# 25%           2.550000
# 50%           7.100000
# 75%           9.675000
# max          16.500000

# %%
print(df.corr())
# Out:
#                      PHEV       BEV       HEV  gas_emission     Total  \
# PHEV             1.000000  0.973914  0.916427      0.121259 -0.081130
# BEV              0.973914  1.000000  0.947908      0.139602 -0.045611
# HEV              0.916427  0.947908  1.000000     -0.045281 -0.271222
# gas_emission     0.121259  0.139602 -0.045281      1.000000  0.312446
# Total           -0.081130 -0.045611 -0.271222      0.312446  1.000000
# billion_mileage  0.392291  0.441985  0.224810      0.765729  0.487001
#
#                  billion_mileage
# PHEV                    0.392291
# BEV                     0.441985
# HEV                     0.224810
# gas_emission            0.765729
# Total                   0.487001
# billion_mileage         1.000000

# %%
corr_pd=df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr_pd,cmap='YlGnBu')
plt.savefig('R2')
plt.show()

df.corr()
# Out:
#                      PHEV       BEV       HEV  gas_emission     Total  \
# PHEV             1.000000  0.973914  0.916427      0.121259 -0.081130
# BEV              0.973914  1.000000  0.947908      0.139602 -0.045611
# HEV              0.916427  0.947908  1.000000     -0.045281 -0.271222
# gas_emission     0.121259  0.139602 -0.045281      1.000000  0.312446
# Total           -0.081130 -0.045611 -0.271222      0.312446  1.000000
# billion_mileage  0.392291  0.441985  0.224810      0.765729  0.487001
#
#                  billion_mileage
# PHEV                    0.392291
# BEV                     0.441985
# HEV                     0.224810
# gas_emission            0.765729
# Total                   0.487001
# billion_mileage         1.000000

# %%
pd.plotting.scatter_matrix(df,alpha=0.5,figsize=(10,8),grid=False,diagonal='kde',marker='o',range_padding=0.1)
# Out:
# array([[<AxesSubplot:xlabel='PHEV', ylabel='PHEV'>,
#         <AxesSubplot:xlabel='BEV', ylabel='PHEV'>,
#         <AxesSubplot:xlabel='HEV', ylabel='PHEV'>,
#         <AxesSubplot:xlabel='gas_emission', ylabel='PHEV'>,
#         <AxesSubplot:xlabel='Total', ylabel='PHEV'>,
#         <AxesSubplot:xlabel='billion_mileage', ylabel='PHEV'>],
#        [<AxesSubplot:xlabel='PHEV', ylabel='BEV'>,
#         <AxesSubplot:xlabel='BEV', ylabel='BEV'>,
#         <AxesSubplot:xlabel='HEV', ylabel='BEV'>,
#         <AxesSubplot:xlabel='gas_emission', ylabel='BEV'>,
#         <AxesSubplot:xlabel='Total', ylabel='BEV'>,
#         <AxesSubplot:xlabel='billion_mileage', ylabel='BEV'>],
#        [<AxesSubplot:xlabel='PHEV', ylabel='HEV'>,
#         <AxesSubplot:xlabel='BEV', ylabel='HEV'>,
#         <AxesSubplot:xlabel='HEV', ylabel='HEV'>,
#         <AxesSubplot:xlabel='gas_emission', ylabel='HEV'>,
#         <AxesSubplot:xlabel='Total', ylabel='HEV'>,
# ...

# %%
import patsy

f1 = 'gas_emission ~ PHEV + BEV  + HEV + Total + billion_mileage'
y, X = patsy.dmatrices(f1, df, return_type='dataframe')

results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           gas_emission   R-squared:                       0.678
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     7.586
# Date:                Mon, 18 Jan 2021   Prob (F-statistic):           0.000547
# Time:                        19:54:25   Log-Likelihood:                -36.810
# No. Observations:                  24   AIC:                             85.62
# Df Residuals:                      18   BIC:                             92.69
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -0.0481      1.203     -0.040      0.969      -2.576       2.480
# ...
